# %% [markdown]
# # Sentiment analysis
#
# ### Sentiment Analysis, or Opinion Mining, is a sub-field of Natural Language Processing (NLP) that tries to identify and extract opinions within a given text.
#
# - sentiment analysis so important because Businesses today are heavily dependent on data. Majority of this data however, is unstructured text coming from sources like emails, chats, social media, surveys, articles, and documents. The micro-blogging content coming from Twitter and Facebook poses serious challenges, not only because of the amount of data involved, but also because of the kind of language used in them to express sentiments, i.e., short forms, memes and emoticons
#
# - sentiment analysis is used in all over the world to analyse the people reaction.
# - Different company use sentiment analysis to analyse the product review.
# - on the basis of product review company take for decision.

# %% [markdown]
# ### Importing the library

# %%
import pandas as pd
import tweepy

# %% [markdown]
# ## VADER Sentiment Analysis
#
# - VADER (Valence Aware Dictionary and sEntiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media.
#
# - VADER uses a combination of A sentiment lexicon is a list of lexical features (e.g., words) which are generally labelled according to their semantic orientation as either positive or negative.
#
# - VADER has been found to be quite successful when dealing with social media texts, NY Times editorials, movie reviews, and product reviews. This is because VADER not only tells about the Positivity and Negativity score but also tells us about how positive or negative a sentiment is.
#
# - VADER performs very well with emojis, slangs and acronyms in sentences.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#Authenticate keys of twitter
consumer_key = 'Enter Here'
consumer_secret = 'Enter Here'
access_token = 'Enter Here'
access_token_secret = 'Enter Here'

# %%
#with the help of key accessing the twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Machine Learning', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @KirkDBorne: Learning Math For #MachineLear...
# 1  Buen articulo sobre la IA en estos momentos: h...
# 2  @radiobotics’ machine learning technology, tha...
# 3  Impact of a combination of quantitative indice...
# 4  Topological Properties of Resting-State fMRI F...
# 5  Performance and clinical impact of machine lea...
# 6  Handmade trileaflet valve design and validatio...
# 7  Prediction of breast cancer risk using a machi...
# 8  RT @IntelBusiness: Improve business processes ...
# 9  RT @ElliottSaslow: We are in a digital arms ra...
# 2019-01-29 13:28:06

# %%
import nltk
# lexicon is considered a corpus since a list of words is also a body of text
nltk.download('lexicon')
# Out:
# [nltk_data] Error loading lexicon: Package 'lexicon' not found in
# [nltk_data]     index
# False

# %%
#creating the object for analysing the polarity
sid = SentimentIntensityAnalyzer()

listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @KirkDBorne: Learning Math For #MachineLear...
# 1   Buen articulo sobre la IA en estos momentos: h...
# 2   @radiobotics’ machine learning technology, tha...
# 3   Impact of a combination of quantitative indice...
# 4   Topological Properties of Resting-State fMRI F...
# 5   Performance and clinical impact of machine lea...
# 6   Handmade trileaflet valve design and validatio...
# 7   Prediction of breast cancer risk using a machi...
# 8   RT @IntelBusiness: Improve business processes ...
# 9   RT @ElliottSaslow: We are in a digital arms ra...
# 10  Increasing Accessibility with Machine Learning...
# 11  Increasing Accessibility with Machine Learning...
# 12  RT @DD_NaNa_: Getting Value from Machine Learn...
# 13  Machine learning is a sweet way to tell if you...
# 14  双曲空間でのMachine Learningの最近の進展 - ABEJA Arts Blog...
# 15  Google's Machine Learning Can Help Drivers Avo...
# 16  I've organized the recent exchange of blog pos...
# 17  Getting Value from Machine Learning Isn’t Abou...
# 18  RT @larsmnagel: I think we are the first Europ...
# 19  RT @AWS_UKI: This is a great watch! @ShafreenS...
# 20  RT @hire_olive: Here is our weekly geek out - ...
# 21  @JoshuaPStarr Feds, states, &amp; districts al...
# 22  "Christelle Marfaing, Data Scientist chez Lydi...
# 23  Looking to introduce AI in your marketing acti...
# 24  Increasing Accessibility with Machine Learning...
# 25  Khan Academy for learning Math https://t.co/BT...
# 26  #IoT, #AI, and machine learning help organizat...
# 27  RT @DotCSV: El estado de la IA en 2019.\n\nhtt...
# 28  RT @MusicComposer1: Interesting....The state o...
# 29  RT @KirkDBorne: One of my all-time favorites &...
# ..                                                ...
# 70  RT @willhillpeople: Would you like to work wor...
# 71  RT @l2k: I wrote another article: Why are Mach...
# 72  Learning Math For Machine Learning And Artific...
# 73  RT @myESR: Explore the fascinating world of AI...
# 74  RT @alosefer: #كنز\nمخزن للبيانات والمعلومات ا...
# 75  Would you like to work work with innovative te...
# 76  RT @Azure: Reduce the time it takes to build m...
# 77  🧐 Es zeichnet sich ein mögliches Plateau beim ...
# 78  RT @KirkDBorne: Learning Math For #MachineLear...
# 79  The state of AI in 2019 https://t.co/17Wu50HWS...
# 80  Here is our weekly geek out - learn how to tra...
# 81  Prepare your data management architecture for ...
# 82  #MachineLearning Across Industries: Belief, In...
# 83  AI, machine learning and big data make @Ciever...
# 84  Professor Rob Tibshirani – one of the authors ...
# 85  RT @DoghouseAI: Increasing accessibility with ...
# 86  Increasing Accessibility with Machine Learning...
# 87  RT @houdaAjawhar: “It’s better, then, to talk ...
# 88  So krempeln künstliche Intelligenz &amp; Machi...
# 89  Increasing Accessibility with Machine Learning...
# 90  Increasing Accessibility with Machine Learning...
# 91  RT @cysecprofs: Big Data, machine learning, da...
# 92  Humans vs machines: AI and machine learning in...
# 93  RT @DoghouseAI: Increasing accessibility with ...
# 94  We can help execute using disparate data and m...
# 95  RT @houdaAjawhar: “It’s better, then, to talk ...
# 96  RT @MindWise_CK: “You’re only as diverse as yo...
# 97  RT @KirkDBorne: Learning Math For #MachineLear...
# 98  RT @chchristiaens: This is what’s happening in...
# 99  RT @Inferences_om: Quels sont les langages et ...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'comp...
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'comp...
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   {'neg': 0.317, 'neu': 0.683, 'pos': 0.0, 'comp...
# 8   {'neg': 0.0, 'neu': 0.573, 'pos': 0.427, 'comp...
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12  {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'comp...
# 13  {'neg': 0.181, 'neu': 0.643, 'pos': 0.175, 'co...
# 14  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15  {'neg': 0.283, 'neu': 0.576, 'pos': 0.141, 'co...
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 17  {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'comp...
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19  {'neg': 0.0, 'neu': 0.812, 'pos': 0.188, 'comp...
# 20  {'neg': 0.076, 'neu': 0.924, 'pos': 0.0, 'comp...
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23  {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'comp...
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 26  {'neg': 0.166, 'neu': 0.607, 'pos': 0.227, 'co...
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29  {'neg': 0.103, 'neu': 0.655, 'pos': 0.241, 'co...
# ..                                                ...
# 70  {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'comp...
# 71  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 72  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 73  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'comp...
# 74  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 75  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'comp...
# 76  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 77  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 78  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 79  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 80  {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'comp...
# 81  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 82  {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'comp...
# 83  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 84  {'neg': 0.155, 'neu': 0.687, 'pos': 0.159, 'co...
# 85  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 86  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 87  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 88  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 89  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 90  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 91  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...
# 92  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 93  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 94  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'comp...
# 95  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'comp...
# 96  {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 97  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...
# 98  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 99  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [100 rows x 2 columns]

# %% [markdown]
# ### The Compound score is a metric that calculates the sum of all the lexicon ratings which have been normalized between -1(most extreme negative) and +1 (most extreme positive).
#
# ![1_G8yV2iaqqfaGfmRPRem2Fw.png](attachment:1_G8yV2iaqqfaGfmRPRem2Fw.png)
